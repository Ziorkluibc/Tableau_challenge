# %%
import pandas as pd
import numpy as np

# %%
csv1 = "2015-citibike-tripdata/1_January/201501-citibike-tripdata_1.csv"
csv2 = "2015-citibike-tripdata/2_February/201502-citibike-tripdata_1.csv"
csv3 = "2015-citibike-tripdata/3_March/201503-citibike-tripdata_1.csv"
csv4 = "2015-citibike-tripdata/4_April/201504-citibike-tripdata_1.csv"
csv5 = "2015-citibike-tripdata/5_May/201505-citibike-tripdata_1.csv"
csv6 = "2015-citibike-tripdata/6_June/201506-citibike-tripdata_1.csv"
csv7a = "2015-citibike-tripdata/7_July/201507-citibike-tripdata_1.csv"
csv7b = "2015-citibike-tripdata/7_July/201507-citibike-tripdata_2.csv"
csv8a = "2015-citibike-tripdata/8_August/201508-citibike-tripdata_1.csv"
csv8b = "2015-citibike-tripdata/8_August/201508-citibike-tripdata_2.csv"
csv9a = "2015-citibike-tripdata/9_September/201509-citibike-tripdata_1.csv"
csv9b = "2015-citibike-tripdata/9_September/201509-citibike-tripdata_2.csv"
csv10a = "2015-citibike-tripdata/10_October/201510-citibike-tripdata_1.csv"
csv10b = "2015-citibike-tripdata/10_October/201510-citibike-tripdata_2.csv"
csv11 = "2015-citibike-tripdata/11_November/201511-citibike-tripdata_1.csv"
csv12 = "2015-citibike-tripdata/12_December/201512-citibike-tripdata_1.csv"

trip_Jan = pd.read_csv(csv1)
trip_Feb = pd.read_csv(csv2)
trip_Mar = pd.read_csv(csv3)
trip_Apr = pd.read_csv(csv4)
trip_May = pd.read_csv(csv5)
trip_Jun = pd.read_csv(csv6)
trip_Jula= pd.read_csv(csv7a)
trip_Julb= pd.read_csv(csv7b)
trip_Auga= pd.read_csv(csv8a)
trip_Augb= pd.read_csv(csv8b)
trip_Septa= pd.read_csv(csv9a)
trip_Septb= pd.read_csv(csv9b)
trip_Octa= pd.read_csv(csv10a)
trip_Octb= pd.read_csv(csv10b)
trip_Nov= pd.read_csv(csv11)
trip_Dec= pd.read_csv(csv12)

# %%
trip_Jan_df = trip_Jan
trip_Feb_df = trip_Feb
trip_Mar_df = trip_Mar
trip_Apr_df = trip_Apr
trip_May_df = trip_May
trip_Jun_df = trip_Jun
trip_Jula_df = trip_Jula
trip_Julb_df = trip_Julb
trip_Auga_df = trip_Auga
trip_Augb_df = trip_Augb
trip_Sepa_df = trip_Septa
trip_Sepb_df = trip_Septb
trip_Octa_df = trip_Octa
trip_Octb_df = trip_Octb
trip_Nov_df = trip_Nov
trip_Dec_df = trip_Dec

# %%
trip_Jan_df = trip_Jan
trip_Jan_df.head(2)
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0          1346  1/1/2015 0:01  1/1/2015 0:24               455
# 1           363  1/1/2015 0:02  1/1/2015 0:08               434
#
#   start station name  start station latitude  start station longitude  \
# 0    1 Ave & E 44 St               40.750020               -73.969053
# 1    9 Ave & W 18 St               40.743174               -74.003664
#
#    end station id          end station name  end station latitude  \
# 0             265  Stanton St & Chrystie St             40.722293
# 1             482           W 15 St & 7 Ave             40.739355
#
#    end station longitude  bikeid    usertype  birth year  gender
# 0             -73.991475   18660  Subscriber      1960.0       2
# 1             -73.999318   16085  Subscriber      1963.0       1

# %%
trip_Dec_df = trip_Jan
trip_Dec_df.head(2)
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0          1346  1/1/2015 0:01  1/1/2015 0:24               455
# 1           363  1/1/2015 0:02  1/1/2015 0:08               434
#
#   start station name  start station latitude  start station longitude  \
# 0    1 Ave & E 44 St               40.750020               -73.969053
# 1    9 Ave & W 18 St               40.743174               -74.003664
#
#    end station id          end station name  end station latitude  \
# 0             265  Stanton St & Chrystie St             40.722293
# 1             482           W 15 St & 7 Ave             40.739355
#
#    end station longitude  bikeid    usertype  birth year  gender
# 0             -73.991475   18660  Subscriber      1960.0       2
# 1             -73.999318   16085  Subscriber      1963.0       1

# %%
trip_Jan_df.dtypes
trip_Feb_df.dtypes
trip_Mar_df.dtypes
trip_Apr_df.dtypes
trip_May_df.dtypes
trip_Jula_df.dtypes
trip_Julb_df.dtypes
trip_Auga_df.dtypes
trip_Augb_df.dtypes
trip_Sepa_df.dtypes
trip_Sepb_df.dtypes
trip_Octa_df.dtypes
trip_Octb_df.dtypes
trip_Nov_df.dtypes
trip_Dec_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                 float64
# gender                       int64
# dtype: object

# %%
trip_Jan_df["gender"] = trip_Jan_df["gender"].astype(str)
trip_Feb_df["gender"] = trip_Feb_df["gender"].astype(str)
trip_Mar_df["gender"] = trip_Mar_df["gender"].astype(str)
trip_Apr_df["gender"] = trip_Apr_df["gender"].astype(str)
trip_May_df["gender"] = trip_May_df["gender"].astype(str)
trip_Jun_df["gender"] = trip_Jun_df["gender"].astype(str)
trip_Jula_df["gender"] = trip_Jula_df["gender"].astype(str)
trip_Julb_df["gender"] = trip_Julb_df["gender"].astype(str)
trip_Auga_df["gender"] = trip_Auga_df["gender"].astype(str)
trip_Augb_df["gender"] = trip_Augb_df["gender"].astype(str)
trip_Sepa_df["gender"] = trip_Sepa_df["gender"].astype(str)
trip_Sepb_df["gender"] = trip_Sepb_df["gender"].astype(str)
trip_Octa_df["gender"] = trip_Octa_df["gender"].astype(str)
trip_Octb_df["gender"] = trip_Octb_df["gender"].astype(str)
trip_Nov_df["gender"] = trip_Nov_df["gender"].astype(str)
trip_Dec_df["gender"] = trip_Dec_df["gender"].astype(str)

# %%
gender_Jan = trip_Jan_df["gender"]
gender_Jan = gender_Jan.replace({"1": "Male", "2": "Female", "0":"unknown"})
trip_Jan_df["gender"] = gender_Jan

trip_Jan_df
# Out:
#         tripduration        starttime       stoptime  start station id  \
# 0               1346    1/1/2015 0:01  1/1/2015 0:24               455
# 1                363    1/1/2015 0:02  1/1/2015 0:08               434
# 2                346    1/1/2015 0:04  1/1/2015 0:10               491
# 3                182    1/1/2015 0:04  1/1/2015 0:07               384
# 4                969    1/1/2015 0:05  1/1/2015 0:21               474
# ...              ...              ...            ...               ...
# 285547           169  1/31/2015 23:57  2/1/2015 0:00               161
# 285548           827  1/31/2015 23:58  2/1/2015 0:12               252
# 285549           798  1/31/2015 23:58  2/1/2015 0:11               127
# 285550           725  1/31/2015 23:58  2/1/2015 0:10               435
# 285551           892  1/31/2015 23:59  2/1/2015 0:14               504
#
#                   start station name  start station latitude  \
# ...

# %%
gender_Feb = trip_Feb_df["gender"]
gender_Feb = gender_Feb.replace({"1": "Male", "2": "Female", "0":"unknown"})
trip_Feb_df["gender"] = gender_Feb
trip_Feb_df
# Out:
#         tripduration        starttime       stoptime  start station id  \
# 0                801    2/1/2015 0:00  2/1/2015 0:14               521
# 1                379    2/1/2015 0:00  2/1/2015 0:07               497
# 2               2474    2/1/2015 0:01  2/1/2015 0:42               281
# 3                818    2/1/2015 0:01  2/1/2015 0:15              2004
# 4                544    2/1/2015 0:01  2/1/2015 0:10               323
# ...              ...              ...            ...               ...
# 196925           747  2/28/2015 23:57  3/1/2015 0:09               414
# 196926           204  2/28/2015 23:58  3/1/2015 0:02               428
# 196927           675  2/28/2015 23:59  3/1/2015 0:11               545
# 196928           651  2/28/2015 23:59  3/1/2015 0:10               396
# 196929           636  2/28/2015 23:59  3/1/2015 0:10               537
#
#                        start station name  start station latitude  \
# ...

# %%
gender_Mar = trip_Mar_df["gender"]
gender_Mar= gender_Mar.replace({"1": "Male", "2": "Female", "0":"unknown"})
trip_Mar_df["gender"] = gender_Mar
trip_Mar_df
# Out:
#         tripduration        starttime         stoptime  start station id  \
# 0                669    3/1/2015 0:00    3/1/2015 0:11               164
# 1                750    3/1/2015 0:01    3/1/2015 0:14               258
# 2                663    3/1/2015 0:01    3/1/2015 0:12               497
# 3                480    3/1/2015 0:02    3/1/2015 0:10               470
# 4               1258    3/1/2015 0:02    3/1/2015 0:23               345
# ...              ...              ...              ...               ...
# 341821           536  3/31/2015 23:58    4/1/2015 0:07               324
# 341822          1030  3/31/2015 23:59    4/1/2015 0:16               495
# 341823           171  3/31/2015 23:59    4/1/2015 0:02               450
# 341824           616  3/31/2015 23:59    4/1/2015 0:09               455
# 341825           227  3/31/2015 23:55  3/31/2015 23:59               477
#
#                  start station name  start station latitude  \
# ...

# %%
gender_Apr = trip_Apr_df["gender"]
gender_Apr= gender_Apr.replace({"1": "Male", "2": "Female", "0":"unknown"})
trip_Apr_df["gender"] = gender_Apr
trip_Apr_df
# Out:
#         tripduration           starttime           stoptime  start station id  \
# 0                241   4/1/2015 00:00:23  4/1/2015 00:04:25               494
# 1                578   4/1/2015 00:00:52  4/1/2015 00:10:31                82
# 2                484   4/1/2015 00:01:28  4/1/2015 00:09:33               223
# 3               1144   4/1/2015 00:01:31  4/1/2015 00:20:36               393
# 4               1023   4/1/2015 00:01:36  4/1/2015 00:18:40               212
# ...              ...                 ...                ...               ...
# 652385           949  4/30/2015 23:59:27  5/1/2015 00:15:16               479
# 652386           205  4/30/2015 23:59:30  5/1/2015 00:02:55               334
# 652387          1413  4/30/2015 23:59:36  5/1/2015 00:23:09               519
# 652388           435  4/30/2015 23:59:40  5/1/2015 00:06:55               323
# 652389           380  4/30/2015 23:59:55  5/1/2015 00:06:15               494
#
# ...

# %%
gender_May = trip_May_df["gender"]
gender_May= gender_May.replace({"1": "Male", "2": "Female", "0":"unknown"})
trip_May_df["gender"] = gender_Mar
trip_May_df
# Out:
#         tripduration           starttime           stoptime  start station id  \
# 0                415   5/1/2015 00:00:11  5/1/2015 00:07:06               477
# 1               1523   5/1/2015 00:00:28  5/1/2015 00:25:52               293
# 2                642   5/1/2015 00:00:52  5/1/2015 00:11:35               380
# 3                367   5/1/2015 00:00:48  5/1/2015 00:06:55               537
# 4               2734   5/1/2015 00:00:51  5/1/2015 00:46:26               426
# ...              ...                 ...                ...               ...
# 961981           541  5/31/2015 23:57:10  6/1/2015 00:06:12               536
# 961982          2147  5/31/2015 23:58:48  6/1/2015 00:34:36               225
# 961983           572  5/31/2015 23:58:55  6/1/2015 00:08:27               157
# 961984           380  5/31/2015 23:59:43  6/1/2015 00:06:04               265
# 961985           750  5/31/2015 23:59:59  6/1/2015 00:12:30               453
#
# ...

# %%
gender_Jun = trip_Jun_df["gender"]
gender_Jun= gender_Jun.replace({"1": "Male", "2": "Female", "0":"unknown"})
trip_Jun_df["gender"] = gender_Jun
trip_Jun_df
# Out:
#         tripduration        starttime       stoptime  start station id  \
# 0               1338    6/1/2015 0:00  6/1/2015 0:22               128
# 1                290    6/1/2015 0:00  6/1/2015 0:05               438
# 2                634    6/1/2015 0:01  6/1/2015 0:11               383
# 3                159    6/1/2015 0:01  6/1/2015 0:04               361
# 4               1233    6/1/2015 0:02  6/1/2015 0:22               382
# ...              ...              ...            ...               ...
# 941214          1053  6/30/2015 23:59  7/1/2015 0:17               323
# 941215          1149  6/30/2015 23:59  7/1/2015 0:18               116
# 941216          3557  6/30/2015 23:59  7/1/2015 0:58               454
# 941217           819  6/30/2015 23:59  7/1/2015 0:13               410
# 941218           667  6/30/2015 23:59  7/1/2015 0:10               308
#
#                  start station name  start station latitude  \
# ...

# %%
gender_Jula = trip_Jula_df["gender"]
gender_Jula= gender_Jula.replace({"1": "Male", "2": "Female", "0":"unknown"})
trip_Jula_df["gender"] = gender_Jula
trip_Jula_df
# Out:
#         tripduration           starttime            stoptime  \
# 0                732   7/1/2015 00:00:03   7/1/2015 00:12:16
# 1                322   7/1/2015 00:00:06   7/1/2015 00:05:29
# 2                790   7/1/2015 00:00:17   7/1/2015 00:13:28
# 3               1228   7/1/2015 00:00:23   7/1/2015 00:20:51
# 4               1383   7/1/2015 00:00:44   7/1/2015 00:23:48
# ...              ...                 ...                 ...
# 999995           205  7/29/2015 17:11:28  7/29/2015 17:14:53
# 999996          1024  7/29/2015 17:11:28  7/29/2015 17:28:33
# 999997           552  7/29/2015 17:11:29  7/29/2015 17:20:41
# 999998           434  7/29/2015 17:11:30  7/29/2015 17:18:44
# 999999           683  7/29/2015 17:11:29  7/29/2015 17:22:53
#
#         start station id        start station name  start station latitude  \
# 0                    489          10 Ave & W 28 St               40.750664
# 1                    304     Broadway & Battery Pl               40.704633
# ...

# %%
gender_Julb = trip_Julb_df["gender"]
gender_Julb= gender_Julb.replace({"1": "Male", "2": "Female", "0":"unknown"})
trip_Julb_df["gender"] = gender_Julb
trip_Julb_df
# Out:
#        tripduration           starttime            stoptime  start station id  \
# 0              1238  7/29/2015 17:11:31  7/29/2015 17:32:09               160
# 1               766  7/29/2015 17:11:28  7/29/2015 17:24:14               328
# 2               661  7/29/2015 17:11:28  7/29/2015 17:22:30               328
# 3              1287  7/29/2015 17:11:31  7/29/2015 17:32:58               508
# 4              3977  7/29/2015 17:11:31  7/29/2015 18:17:48               459
# ...             ...                 ...                 ...               ...
# 85671           275  7/31/2015 23:59:40   8/1/2015 00:04:15               383
# 85672           530  7/31/2015 23:59:41   8/1/2015 00:08:32               455
# 85673           273  7/31/2015 23:59:42   8/1/2015 00:04:15               383
# 85674          1273  7/31/2015 23:59:56   8/1/2015 00:21:09               477
# 85675          1667  7/31/2015 23:59:59   8/1/2015 00:27:46              2021
#
# ...

# %%
gender_Auga = trip_Auga_df["gender"]
gender_Auga= gender_Auga.replace({"1": "Male", "2": "Female", "0":"unknown"})
trip_Auga_df["gender"] = gender_Auga
trip_Auga_df
# Out:
#         tripduration           starttime            stoptime  \
# 0               1202   8/1/2015 00:00:04   8/1/2015 00:20:07
# 1                301   8/1/2015 00:00:05   8/1/2015 00:05:06
# 2                431   8/1/2015 00:00:06   8/1/2015 00:07:18
# 3                273   8/1/2015 00:00:09   8/1/2015 00:04:43
# 4               1256   8/1/2015 00:00:17   8/1/2015 00:21:13
# ...              ...                 ...                 ...
# 999995         17084  8/27/2015 11:08:11  8/27/2015 15:52:55
# 999996           555  8/27/2015 11:08:17  8/27/2015 11:17:33
# 999997           500  8/27/2015 11:08:17  8/27/2015 11:16:38
# 999998           817  8/27/2015 11:08:18  8/27/2015 11:21:56
# 999999           679  8/27/2015 11:08:18  8/27/2015 11:19:38
#
#         start station id        start station name  start station latitude  \
# 0                    168           W 18 St & 6 Ave               40.739713
# 1                    450           W 49 St & 8 Ave               40.762272
# ...

# %%
gender_Sepa = trip_Sepa_df["gender"]
gender_Sepa= gender_Sepa.replace({"1": "Male", "2": "Female", "0":"unknown"})
trip_Sepa_df["gender"] = gender_Sepa
trip_Sepa_df
# Out:
#         tripduration           starttime            stoptime  \
# 0                288   9/1/2015 00:00:00   9/1/2015 00:04:48
# 1                165   9/1/2015 00:00:00   9/1/2015 00:02:45
# 2                367   9/1/2015 00:00:01   9/1/2015 00:06:08
# 3                926   9/1/2015 00:00:07   9/1/2015 00:15:34
# 4                658   9/1/2015 00:00:09   9/1/2015 00:11:07
# ...              ...                 ...                 ...
# 999995           168  9/24/2015 16:56:30  9/24/2015 16:59:18
# 999996           791  9/24/2015 16:56:32  9/24/2015 17:09:44
# 999997           274  9/24/2015 16:56:34  9/24/2015 17:01:09
# 999998           856  9/24/2015 16:56:34  9/24/2015 17:10:51
# 999999          1553  9/24/2015 16:56:34  9/24/2015 17:22:27
#
#         start station id           start station name  start station latitude  \
# 0                    263     Elizabeth St & Hester St               40.717290
# ...

# %%
gender_Sepb = trip_Sepb_df["gender"]
gender_Sepb= gender_Sepb.replace({"1": "Male", "2": "Female", "0":"unknown"})
trip_Sepb_df["gender"] = gender_Sepb
trip_Sepb_df
# Out:
#         tripduration           starttime            stoptime  \
# 0               1052  9/24/2015 16:56:35  9/24/2015 17:14:07
# 1                560  9/24/2015 16:56:36  9/24/2015 17:05:56
# 2                341  9/24/2015 16:56:35  9/24/2015 17:02:17
# 3                443  9/24/2015 16:56:38  9/24/2015 17:04:01
# 4                307  9/24/2015 16:56:38  9/24/2015 17:01:45
# ...              ...                 ...                 ...
# 289694          1200  9/30/2015 23:59:07  10/1/2015 00:19:07
# 289695          1195  9/30/2015 23:59:10  10/1/2015 00:19:05
# 289696           652  9/30/2015 23:59:44  10/1/2015 00:10:37
# 289697          1733  9/30/2015 23:59:48  10/1/2015 00:28:42
# 289698          1106  9/30/2015 23:59:57  10/1/2015 00:18:24
#
#         start station id        start station name  start station latitude  \
# 0                    459          W 20 St & 11 Ave               40.746745
# 1                   2021           W 45 St & 8 Ave               40.759291
# ...

# %%
gender_Octa = trip_Octa_df["gender"]
gender_Octa= gender_Octa.replace({"1": "Male", "2": "Female", "0":"unknown"})
trip_Octa_df["gender"] = gender_Octa
trip_Octa_df
# Out:
#         tripduration            starttime             stoptime  \
# 0                171   10/1/2015 00:00:02   10/1/2015 00:02:54
# 1                593   10/1/2015 00:00:02   10/1/2015 00:09:55
# 2                233   10/1/2015 00:00:11   10/1/2015 00:04:05
# 3                250   10/1/2015 00:00:15   10/1/2015 00:04:25
# 4                528   10/1/2015 00:00:17   10/1/2015 00:09:05
# ...              ...                  ...                  ...
# 999995           239  10/26/2015 13:09:55  10/26/2015 13:13:54
# 999996           275  10/26/2015 13:10:01  10/26/2015 13:14:36
# 999997           715  10/26/2015 13:10:01  10/26/2015 13:21:57
# 999998          1378  10/26/2015 13:10:04  10/26/2015 13:33:03
# 999999           514  10/26/2015 13:10:08  10/26/2015 13:18:43
#
#         start station id           start station name  start station latitude  \
# 0                    388             W 26 St & 10 Ave               40.749718
# ...

# %%
gender_Octb = trip_Octb_df["gender"]
gender_Octb= gender_Octb.replace({"1": "Male", "2": "Female", "0":"unknown"})
trip_Octb_df["gender"] = gender_Octb
trip_Octb_df
# Out:
#         tripduration            starttime             stoptime  \
# 0                555  10/26/2015 13:10:10  10/26/2015 13:19:25
# 1                818  10/26/2015 13:10:19  10/26/2015 13:23:58
# 2                400  10/26/2015 13:10:18  10/26/2015 13:16:58
# 3                513  10/26/2015 13:10:20  10/26/2015 13:18:53
# 4                233  10/26/2015 13:10:21  10/26/2015 13:14:14
# ...              ...                  ...                  ...
# 212272          1924  10/31/2015 23:59:46   11/1/2015 00:31:50
# 212273           711  10/31/2015 23:59:50   11/1/2015 00:11:42
# 212274           621  10/31/2015 23:59:54   11/1/2015 00:10:15
# 212275           632  10/31/2015 23:59:56   11/1/2015 00:10:29
# 212276           807  10/31/2015 23:59:57   11/1/2015 00:13:24
#
#         start station id                 start station name  \
# 0                    480                   W 53 St & 10 Ave
# 1                    281  Grand Army Plaza & Central Park S
# ...

# %%
gender_Nov = trip_Nov_df["gender"]
gender_Nov= gender_Nov.replace({"1": "Male", "2": "Female", "0":"unknown"})
trip_Nov_df["gender"] = gender_Nov
trip_Nov_df
# Out:
#         tripduration            starttime            stoptime  \
# 0               1110   11/1/2015 00:00:00  11/1/2015 00:18:31
# 1               1094   11/1/2015 00:00:01  11/1/2015 00:18:15
# 2                520   11/1/2015 00:00:05  11/1/2015 00:08:45
# 3                753   11/1/2015 00:00:15  11/1/2015 00:12:48
# 4                353   11/1/2015 00:00:22  11/1/2015 00:06:15
# ...              ...                  ...                 ...
# 987240           133  11/30/2015 23:58:36  12/1/2015 00:00:49
# 987241           495  11/30/2015 23:58:42  12/1/2015 00:06:58
# 987242          1374  11/30/2015 23:58:48  12/1/2015 00:21:43
# 987243           229  11/30/2015 23:59:01  12/1/2015 00:02:51
# 987244           234  11/30/2015 23:59:11  12/1/2015 00:03:05
#
#         start station id            start station name  \
# 0                    537       Lexington Ave & E 24 St
# 1                    537       Lexington Ave & E 24 St
# ...

# %%
gender_Dec = trip_Dec_df["gender"]
gender_Dec= gender_Dec.replace({"1": "Male", "2": "Female", "0":"unknown"})
trip_Dec_df["gender"] = gender_Dec
trip_Dec_df
# Out:
#         tripduration        starttime       stoptime  start station id  \
# 0               1346    1/1/2015 0:01  1/1/2015 0:24               455
# 1                363    1/1/2015 0:02  1/1/2015 0:08               434
# 2                346    1/1/2015 0:04  1/1/2015 0:10               491
# 3                182    1/1/2015 0:04  1/1/2015 0:07               384
# 4                969    1/1/2015 0:05  1/1/2015 0:21               474
# ...              ...              ...            ...               ...
# 285547           169  1/31/2015 23:57  2/1/2015 0:00               161
# 285548           827  1/31/2015 23:58  2/1/2015 0:12               252
# 285549           798  1/31/2015 23:58  2/1/2015 0:11               127
# 285550           725  1/31/2015 23:58  2/1/2015 0:10               435
# 285551           892  1/31/2015 23:59  2/1/2015 0:14               504
#
#                   start station name  start station latitude  \
# ...

# %%
current_year = 2015

trip_Jan_df = trip_Jan_df.dropna(subset=['birth year'])

# Calculate age
birth_year_Jan = trip_Jan_df["birth year"]
age = current_year - birth_year_Jan

# Add the 'age' column to the DataFrame
trip_Jan_df['age'] = age

# Display the DataFrame
trip_Jan_df
# Out:
# /var/folders/nh/8v2vnxrx4zjf2bjtfqnchp600000gn/T/ipykernel_33828/3064545761.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trip_Jan_df['age'] = age
#         tripduration        starttime       stoptime  start station id  \
# 0               1346    1/1/2015 0:01  1/1/2015 0:24               455
# 1                363    1/1/2015 0:02  1/1/2015 0:08               434
# 2                346    1/1/2015 0:04  1/1/2015 0:10               491
# 3                182    1/1/2015 0:04  1/1/2015 0:07               384
# 4                969    1/1/2015 0:05  1/1/2015 0:21               474
# ...              ...              ...            ...               ...
# 285547           169  1/31/2015 23:57  2/1/2015 0:00               161
# ...

# %%
current_year = 2015
trip_Feb_df = trip_Feb_df.dropna(subset=['birth year'])
birth_year_Feb = trip_Feb_df["birth year"]
age = current_year - birth_year_Feb
trip_Feb_df['age'] = age
trip_Feb_df
# Out:
# /var/folders/nh/8v2vnxrx4zjf2bjtfqnchp600000gn/T/ipykernel_33828/3374229424.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trip_Feb_df['age'] = age
#         tripduration        starttime       stoptime  start station id  \
# 0                801    2/1/2015 0:00  2/1/2015 0:14               521
# 1                379    2/1/2015 0:00  2/1/2015 0:07               497
# 2               2474    2/1/2015 0:01  2/1/2015 0:42               281
# 3                818    2/1/2015 0:01  2/1/2015 0:15              2004
# 4                544    2/1/2015 0:01  2/1/2015 0:10               323
# ...              ...              ...            ...               ...
# 196925           747  2/28/2015 23:57  3/1/2015 0:09               414
# ...

# %%
current_year = 2015
trip_Mar_df = trip_Mar_df.dropna(subset=['birth year'])
birth_year_Mar = trip_Mar_df["birth year"]
age = current_year - birth_year_Mar
trip_Mar_df['age'] = age
trip_Mar_df
# Out:
# /var/folders/nh/8v2vnxrx4zjf2bjtfqnchp600000gn/T/ipykernel_33828/3969153822.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trip_Mar_df['age'] = age
#         tripduration        starttime         stoptime  start station id  \
# 0                669    3/1/2015 0:00    3/1/2015 0:11               164
# 1                750    3/1/2015 0:01    3/1/2015 0:14               258
# 3                480    3/1/2015 0:02    3/1/2015 0:10               470
# 4               1258    3/1/2015 0:02    3/1/2015 0:23               345
# 5                363    3/1/2015 0:03    3/1/2015 0:09               380
# ...              ...              ...              ...               ...
# ...

# %%
current_year = 2015
trip_Apr_df = trip_Apr_df.dropna(subset=['birth year'])
birth_year_Apr = trip_Apr_df["birth year"]
age = current_year - birth_year_Apr
trip_Apr_df['age'] = age
trip_Apr_df
# Out:
# /var/folders/nh/8v2vnxrx4zjf2bjtfqnchp600000gn/T/ipykernel_33828/1706684695.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trip_Apr_df['age'] = age
#         tripduration           starttime           stoptime  start station id  \
# 0                241   4/1/2015 00:00:23  4/1/2015 00:04:25               494
# 1                578   4/1/2015 00:00:52  4/1/2015 00:10:31                82
# 2                484   4/1/2015 00:01:28  4/1/2015 00:09:33               223
# 3               1144   4/1/2015 00:01:31  4/1/2015 00:20:36               393
# 4               1023   4/1/2015 00:01:36  4/1/2015 00:18:40               212
# ...              ...                 ...                ...               ...
# ...

# %%
current_year = 2015
trip_May_df = trip_May_df.dropna(subset=['birth year'])
birth_year_May = trip_May_df["birth year"]
age = current_year - birth_year_May
trip_May_df['age'] = age
trip_May_df
# Out:
# /var/folders/nh/8v2vnxrx4zjf2bjtfqnchp600000gn/T/ipykernel_33828/3345179293.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trip_May_df['age'] = age
#         tripduration           starttime           stoptime  start station id  \
# 0                415   5/1/2015 00:00:11  5/1/2015 00:07:06               477
# 2                642   5/1/2015 00:00:52  5/1/2015 00:11:35               380
# 3                367   5/1/2015 00:00:48  5/1/2015 00:06:55               537
# 4               2734   5/1/2015 00:00:51  5/1/2015 00:46:26               426
# 5                359   5/1/2015 00:01:07  5/1/2015 00:07:07               439
# ...              ...                 ...                ...               ...
# ...

# %%
current_year = 2015
trip_Jun_df = trip_Jun_df.dropna(subset=['birth year'])
birth_year_Jun = trip_Jun_df["birth year"]
age = current_year - birth_year_Jun
trip_Jun_df['age'] = age
trip_Jun_df
# Out:
# /var/folders/nh/8v2vnxrx4zjf2bjtfqnchp600000gn/T/ipykernel_33828/321640010.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trip_Jun_df['age'] = age
#         tripduration        starttime       stoptime  start station id  \
# 0               1338    6/1/2015 0:00  6/1/2015 0:22               128
# 1                290    6/1/2015 0:00  6/1/2015 0:05               438
# 2                634    6/1/2015 0:01  6/1/2015 0:11               383
# 3                159    6/1/2015 0:01  6/1/2015 0:04               361
# 5                690    6/1/2015 0:03  6/1/2015 0:15               284
# ...              ...              ...            ...               ...
# 941211           168  6/30/2015 23:59  7/1/2015 0:02               529
# ...

# %%
current_year = 2015
trip_Jula_df = trip_Jula_df.dropna(subset=['birth year'])
birth_year_Jula = trip_Jula_df["birth year"]
age = current_year - birth_year_Jula
trip_Jula_df['age'] = age
trip_Jula_df
# Out:
# /var/folders/nh/8v2vnxrx4zjf2bjtfqnchp600000gn/T/ipykernel_33828/624425043.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trip_Jula_df['age'] = age
#         tripduration           starttime            stoptime  \
# 0                732   7/1/2015 00:00:03   7/1/2015 00:12:16
# 1                322   7/1/2015 00:00:06   7/1/2015 00:05:29
# 2                790   7/1/2015 00:00:17   7/1/2015 00:13:28
# 3               1228   7/1/2015 00:00:23   7/1/2015 00:20:51
# 4               1383   7/1/2015 00:00:44   7/1/2015 00:23:48
# ...              ...                 ...                 ...
# 999995           205  7/29/2015 17:11:28  7/29/2015 17:14:53
# 999996          1024  7/29/2015 17:11:28  7/29/2015 17:28:33
# ...

# %%
current_year = 2015
trip_Julb_df = trip_Julb_df.dropna(subset=['birth year'])
birth_year_Julb = trip_Julb_df["birth year"]
age = current_year - birth_year_Julb
trip_Julb_df['age'] = age
trip_Julb_df
# Out:
# /var/folders/nh/8v2vnxrx4zjf2bjtfqnchp600000gn/T/ipykernel_33828/2465377928.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trip_Julb_df['age'] = age
#        tripduration           starttime            stoptime  start station id  \
# 0              1238  7/29/2015 17:11:31  7/29/2015 17:32:09               160
# 1               766  7/29/2015 17:11:28  7/29/2015 17:24:14               328
# 2               661  7/29/2015 17:11:28  7/29/2015 17:22:30               328
# 3              1287  7/29/2015 17:11:31  7/29/2015 17:32:58               508
# 5              1624  7/29/2015 17:11:30  7/29/2015 17:38:35              2023
# ...             ...                 ...                 ...               ...
# ...

# %%
current_year = 2015
trip_Auga_df = trip_Auga_df.dropna(subset=['birth year'])
birth_year_Auga = trip_Auga_df["birth year"]
age = current_year - birth_year_Auga
trip_Auga_df['age'] = age
trip_Auga_df
# Out:
# /var/folders/nh/8v2vnxrx4zjf2bjtfqnchp600000gn/T/ipykernel_33828/306306543.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trip_Auga_df['age'] = age
#         tripduration           starttime            stoptime  \
# 0               1202   8/1/2015 00:00:04   8/1/2015 00:20:07
# 1                301   8/1/2015 00:00:05   8/1/2015 00:05:06
# 2                431   8/1/2015 00:00:06   8/1/2015 00:07:18
# 3                273   8/1/2015 00:00:09   8/1/2015 00:04:43
# 4               1256   8/1/2015 00:00:17   8/1/2015 00:21:13
# ...              ...                 ...                 ...
# 999993           569  8/27/2015 11:08:11  8/27/2015 11:17:41
# 999996           555  8/27/2015 11:08:17  8/27/2015 11:17:33
# ...

# %%
current_year = 2015
trip_Augb_df= trip_Augb_df.dropna(subset=['birth year'])
trip_Augb_df = trip_Augb
birth_year_Augb = trip_Augb_df["birth year"]
age = current_year - birth_year_Augb
trip_Augb_df['age'] = age
trip_Augb_df
# Out:
#         tripduration           starttime            stoptime  \
# 0                675  8/27/2015 11:08:19  8/27/2015 11:19:34
# 1                192  8/27/2015 11:08:20  8/27/2015 11:11:32
# 2               1617  8/27/2015 11:08:23  8/27/2015 11:35:20
# 3                861  8/27/2015 11:08:24  8/27/2015 11:22:45
# 4                178  8/27/2015 11:08:27  8/27/2015 11:11:25
# ...              ...                 ...                 ...
# 179039           423  8/31/2015 23:58:43   9/1/2015 00:05:47
# 179040          1021  8/31/2015 23:58:54   9/1/2015 00:15:56
# 179041          1896  8/31/2015 23:59:11   9/1/2015 00:30:47
# 179042           826  8/31/2015 23:59:16   9/1/2015 00:13:02
# 179043           105  8/31/2015 23:59:41   9/1/2015 00:01:26
#
#         start station id           start station name  start station latitude  \
# 0                    127        Barrow St & Hudson St               40.731724
# ...

# %%
current_year = 2015
trip_Sepa_df= trip_Sepa_df.dropna(subset=['birth year'])
birth_year_Sepa = trip_Sepa_df["birth year"]
age = current_year - birth_year_Sepa
trip_Sepa_df['age'] = age
trip_Sepa_df
# Out:
# /var/folders/nh/8v2vnxrx4zjf2bjtfqnchp600000gn/T/ipykernel_33828/2841196208.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trip_Sepa_df['age'] = age
#         tripduration           starttime            stoptime  \
# 0                288   9/1/2015 00:00:00   9/1/2015 00:04:48
# 1                165   9/1/2015 00:00:00   9/1/2015 00:02:45
# 3                926   9/1/2015 00:00:07   9/1/2015 00:15:34
# 4                658   9/1/2015 00:00:09   9/1/2015 00:11:07
# 5                392   9/1/2015 00:00:13   9/1/2015 00:06:46
# ...              ...                 ...                 ...
# 999995           168  9/24/2015 16:56:30  9/24/2015 16:59:18
# 999996           791  9/24/2015 16:56:32  9/24/2015 17:09:44
# ...

# %%
current_year = 2015
trip_Sepb_df= trip_Sepb_df.dropna(subset=['birth year'])
birth_year_Sepb = trip_Sepb_df["birth year"]
age = current_year - birth_year_Sepb
trip_Sepb_df['age'] = age
trip_Sepb_df
# Out:
# /var/folders/nh/8v2vnxrx4zjf2bjtfqnchp600000gn/T/ipykernel_33828/2257070069.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trip_Sepb_df['age'] = age
#         tripduration           starttime            stoptime  \
# 1                560  9/24/2015 16:56:36  9/24/2015 17:05:56
# 2                341  9/24/2015 16:56:35  9/24/2015 17:02:17
# 3                443  9/24/2015 16:56:38  9/24/2015 17:04:01
# 4                307  9/24/2015 16:56:38  9/24/2015 17:01:45
# 5                792  9/24/2015 16:56:39  9/24/2015 17:09:51
# ...              ...                 ...                 ...
# 289692           516  9/30/2015 23:58:44  10/1/2015 00:07:21
# 289693           203  9/30/2015 23:58:56  10/1/2015 00:02:19
# ...

# %%
current_year = 2015
trip_Octa_df= trip_Octa_df.dropna(subset=['birth year'])
birth_year_Octa = trip_Octa_df["birth year"]
age = current_year - birth_year_Octa
trip_Octa_df['age'] = age
trip_Octa_df
# Out:
# /var/folders/nh/8v2vnxrx4zjf2bjtfqnchp600000gn/T/ipykernel_33828/3742522340.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trip_Octa_df['age'] = age
#         tripduration            starttime             stoptime  \
# 0                171   10/1/2015 00:00:02   10/1/2015 00:02:54
# 1                593   10/1/2015 00:00:02   10/1/2015 00:09:55
# 2                233   10/1/2015 00:00:11   10/1/2015 00:04:05
# 3                250   10/1/2015 00:00:15   10/1/2015 00:04:25
# 6               1185   10/1/2015 00:00:22   10/1/2015 00:20:07
# ...              ...                  ...                  ...
# 999995           239  10/26/2015 13:09:55  10/26/2015 13:13:54
# 999996           275  10/26/2015 13:10:01  10/26/2015 13:14:36
# ...

# %%
current_year = 2015
trip_Octb_df= trip_Octb_df.dropna(subset=['birth year'])
birth_year_Octb = trip_Octb_df["birth year"]
age = current_year - birth_year_Octb
trip_Octb_df['age'] = age
trip_Octb_df
# Out:
# /var/folders/nh/8v2vnxrx4zjf2bjtfqnchp600000gn/T/ipykernel_33828/51131478.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trip_Octb_df['age'] = age
#         tripduration            starttime             stoptime  \
# 0                555  10/26/2015 13:10:10  10/26/2015 13:19:25
# 1                818  10/26/2015 13:10:19  10/26/2015 13:23:58
# 2                400  10/26/2015 13:10:18  10/26/2015 13:16:58
# 3                513  10/26/2015 13:10:20  10/26/2015 13:18:53
# 4                233  10/26/2015 13:10:21  10/26/2015 13:14:14
# ...              ...                  ...                  ...
# 212272          1924  10/31/2015 23:59:46   11/1/2015 00:31:50
# 212273           711  10/31/2015 23:59:50   11/1/2015 00:11:42
# ...

# %%
current_year = 2015
trip_Nov_df= trip_Nov_df.dropna(subset=['birth year'])
birth_year_Nov = trip_Nov_df["birth year"]
age = current_year - birth_year_Nov
trip_Nov_df['age'] = age
trip_Nov_df
# Out:
# /var/folders/nh/8v2vnxrx4zjf2bjtfqnchp600000gn/T/ipykernel_33828/1954945889.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trip_Nov_df['age'] = age
#         tripduration            starttime            stoptime  \
# 0               1110   11/1/2015 00:00:00  11/1/2015 00:18:31
# 1               1094   11/1/2015 00:00:01  11/1/2015 00:18:15
# 2                520   11/1/2015 00:00:05  11/1/2015 00:08:45
# 3                753   11/1/2015 00:00:15  11/1/2015 00:12:48
# 4                353   11/1/2015 00:00:22  11/1/2015 00:06:15
# ...              ...                  ...                 ...
# 987240           133  11/30/2015 23:58:36  12/1/2015 00:00:49
# 987241           495  11/30/2015 23:58:42  12/1/2015 00:06:58
# ...

# %%
current_year = 2015
trip_Dec_df= trip_Dec_df.dropna(subset=['birth year'])
birth_year_Dec = trip_Dec_df["birth year"]
age = current_year - birth_year_Dec
trip_Dec_df['age'] = age
trip_Dec_df
# Out:
# /var/folders/nh/8v2vnxrx4zjf2bjtfqnchp600000gn/T/ipykernel_33828/607344561.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trip_Dec_df['age'] = age
#         tripduration        starttime       stoptime  start station id  \
# 0               1346    1/1/2015 0:01  1/1/2015 0:24               455
# 1                363    1/1/2015 0:02  1/1/2015 0:08               434
# 2                346    1/1/2015 0:04  1/1/2015 0:10               491
# 3                182    1/1/2015 0:04  1/1/2015 0:07               384
# 4                969    1/1/2015 0:05  1/1/2015 0:21               474
# ...              ...              ...            ...               ...
# 285547           169  1/31/2015 23:57  2/1/2015 0:00               161
# ...

# %%
trip_Jan_df.to_csv("Cleaned Data", index=False, header=True)

# %%
trip_Augb_df = trip_Augb
trip_Augb_df
# Out:
#         tripduration           starttime            stoptime  \
# 0                675  8/27/2015 11:08:19  8/27/2015 11:19:34
# 1                192  8/27/2015 11:08:20  8/27/2015 11:11:32
# 2               1617  8/27/2015 11:08:23  8/27/2015 11:35:20
# 3                861  8/27/2015 11:08:24  8/27/2015 11:22:45
# 4                178  8/27/2015 11:08:27  8/27/2015 11:11:25
# ...              ...                 ...                 ...
# 179039           423  8/31/2015 23:58:43   9/1/2015 00:05:47
# 179040          1021  8/31/2015 23:58:54   9/1/2015 00:15:56
# 179041          1896  8/31/2015 23:59:11   9/1/2015 00:30:47
# 179042           826  8/31/2015 23:59:16   9/1/2015 00:13:02
# 179043           105  8/31/2015 23:59:41   9/1/2015 00:01:26
#
#         start station id           start station name  start station latitude  \
# 0                    127        Barrow St & Hudson St               40.731724
# ...

# %%
trip_Jan_df = trip_Jan
trip_Jan_df
# trip_Jan_df = pd.DataFrame({"data": ["January_2015"]})
csv_file_path = "Clean_Data/January_2015.csv"
# os.makedirs(os.path.dirname(csv_file_path), exist_ok=True)
trip_Jan_df.to_csv(csv_file_path, index=False)
# txt_file_path = "Desktop/Module 18/Assignment/Clean_Data/Clean_Data.txt"
# with open(txt_file_path, "w") as file:
#     file.write(csv_file_path)

print(f"CSV file saved to {csv_file_path}.")
# Out:
# CSV file saved to Clean_Data/January_2015.csv.

# %%
trip_Feb_df = trip_Feb
trip_Jan_df

csv_file_path = "Clean_Data/February_2015.csv"

trip_Feb_df.to_csv(csv_file_path, index=False)
print(f"CSV file saved to {csv_file_path}.")
# Out:
# CSV file saved to Clean_Data/February_2015.csv.

# %%
trip_Mar_df = trip_Mar
trip_Mar_df
csv_file_path = "Clean_Data/March_2015.csv"
trip_Mar_df.to_csv(csv_file_path, index=False)
print(f"CSV file saved to {csv_file_path}.")
# Out:
# CSV file saved to Clean_Data/March_2015.csv.

# %%
trip_Apr_df = trip_Apr
trip_Apr_df
csv_file_path = "Clean_Data/April_2015.csv"
trip_Apr_df.to_csv(csv_file_path, index=False)
print(f"CSV file saved to {csv_file_path}.")
# Out:
# CSV file saved to Clean_Data/April_2015.csv.

# %%
trip_May_df = trip_May
trip_May_df
csv_file_path = "Clean_Data/May_2015.csv"
trip_May_df.to_csv(csv_file_path, index=False)
print(f"CSV file saved to {csv_file_path}.")
# Out:
# CSV file saved to Clean_Data/May_2015.csv.

# %%
trip_Jun_df = trip_Jun
trip_Jun_df
csv_file_path = "Clean_Data/June_2015.csv"
trip_Jun_df.to_csv(csv_file_path, index=False)
print(f"CSV file saved to {csv_file_path}.")
# Out:
# CSV file saved to Clean_Data/June_2015.csv.

# %%
trip_Jula_df = trip_Jula
trip_Jula_df
csv_file_path = "Clean_Data/July_a_2015.csv"
trip_Jula_df.to_csv(csv_file_path, index=False)
print(f"CSV file saved to {csv_file_path}.")
# Out:
# CSV file saved to Clean_Data/July_a_2015.csv.

# %%
trip_Julb_df = trip_Julb
trip_Julb_df
csv_file_path = "Clean_Data/July_b_2015.csv"
trip_Julb_df.to_csv(csv_file_path, index=False)
print(f"CSV file saved to {csv_file_path}.")
# Out:
# CSV file saved to Clean_Data/July_b_2015.csv.

# %%
trip_Auga_df = trip_Auga
trip_Auga_df
csv_file_path = "Clean_Data/August_2015.csv"
trip_Auga_df.to_csv(csv_file_path, index=False)
print(f"CSV file saved to {csv_file_path}.")
# Out:
# CSV file saved to Clean_Data/August_2015.csv.

# %%
trip_Sepa_df = trip_Septa
trip_Sepa_df
csv_file_path = "Clean_Data/September_a_2015.csv"
trip_Sepa_df.to_csv(csv_file_path, index=False)
print(f"CSV file saved to {csv_file_path}.")
# Out:
# CSV file saved to Clean_Data/September_a_2015.csv.

# %%
trip_Sepb_df = trip_Septb
trip_Sepb_df
csv_file_path = "Clean_Data/September_b_2015.csv"
trip_Sepb_df.to_csv(csv_file_path, index=False)
print(f"CSV file saved to {csv_file_path}.")
# Out:
# CSV file saved to Clean_Data/September_b_2015.csv.

# %%
trip_Octa_df = trip_Octa
trip_Octa_df
csv_file_path = "Clean_Data/October_a_2015.csv"
trip_Octa_df.to_csv(csv_file_path, index=False)
print(f"CSV file saved to {csv_file_path}.")
# Out:
# CSV file saved to Clean_Data/October_a_2015.csv.

# %%
trip_Octb_df = trip_Octb
trip_Octb_df
csv_file_path = "Clean_Data/October_b_2015.csv"
trip_Octb_df.to_csv(csv_file_path, index=False)
print(f"CSV file saved to {csv_file_path}.")
# Out:
# CSV file saved to Clean_Data/October_b_2015.csv.

# %%
trip_Nov_df = trip_Nov
trip_Nov_df
csv_file_path = "Clean_Data/November_2015.csv"
trip_Nov_df.to_csv(csv_file_path, index=False)
print(f"CSV file saved to {csv_file_path}.")
# Out:
# CSV file saved to Clean_Data/November_2015.csv.

# %%
trip_Dec_df = trip_Dec
trip_Dec_df
csv_file_path = "Clean_Data/December_2015.csv"
trip_Dec_df.to_csv(csv_file_path, index=False)
print(f"CSV file saved to {csv_file_path}.")
# Out:
# CSV file saved to Clean_Data/December_2015.csv.
